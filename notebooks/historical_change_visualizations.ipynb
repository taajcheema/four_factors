# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn

from sklearn import linear_model

df = pd.read_excel("per_100_possessions.xlsx")
df.head()
# Out:
#    Rk   Season   Lg   Age   Ht   Wt     G    FG   FGA    3P  ...    PTS  \
# 0   1  2019-20  NBA  26.0  6-6  216   971  40.5  88.0  12.0  ...  110.4
# 1   2  2018-19  NBA  26.3  6-6  217  1230  40.8  88.6  11.3  ...  110.4
# 2   3  2017-18  NBA  26.4  6-7  219  1230  40.5  87.9  10.7  ...  108.6
# 3   4  2016-17  NBA  26.6  6-7  220  1230  40.2  88.0   9.9  ...  108.8
# 4   5  2015-16  NBA  26.7  6-7  221  1230  39.6  87.6   8.8  ...  106.4
#
#      FG%    3P%    FT%   Pace   eFG%  TOV%  ORB%  FT/FGA   ORtg
# 0  0.460  0.357  0.771  100.2  0.528  12.8  22.6   0.199  110.4
# 1  0.461  0.355  0.766  100.0  0.524  12.4  22.9   0.198  110.4
# 2  0.460  0.362  0.767   97.3  0.521  13.0  22.3   0.193  108.6
# 3  0.457  0.358  0.772   96.4  0.514  12.7  23.3   0.209  108.8
# 4  0.452  0.354  0.757   95.8  0.502  13.2  23.8   0.209  106.4
#
# [5 rows x 31 columns]

# %%
# Effective Field Goal % 

plt.figure(figsize=(20,9))
sns.lineplot(data=df, x='Season',y='eFG%')
plt.suptitle('NBA Effective Field Goal % 2000 - 2020', 
              fontsize=16, fontweight='bold')

plt.savefig('eFG%.png')

# %%
# Turnover % 

plt.figure(figsize=(20,9))
sns.lineplot(data=df, x='Season',y='TOV%')
plt.suptitle('NBA Turnover % 2000 - 2020', 
              fontsize=16, fontweight='bold')

plt.savefig('turnovers.png')

# %%
# Offensive Rebound % 

plt.figure(figsize=(20,9))
sns.lineplot(data=df, x='Season',y='ORB%')
plt.suptitle('NBA Offensive Rebound % 2000 - 2020', 
              fontsize=16, fontweight='bold')
plt.savefig('OREB%.png')

# %%
# Free Throw Factor 

plt.figure(figsize=(20,9))
sns.lineplot(data=df, x='Season',y='FT/FGA')
plt.suptitle('NBA Free Throw Factor 2000 - 2020', 
              fontsize=16, fontweight='bold')
plt.savefig('FTF.png')

# %%
# Points

plt.figure(figsize=(20,9))
sns.lineplot(data=df, x='Season',y='PTS')
plt.suptitle('NBA Points per Game 2000 - 2020', 
              fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'NBA Points per Game 2000 - 2020')

# %%
# Effective Field Goal % 

plt.figure(figsize=(20,9))
sns.lineplot(data=df, x='Season',y='eFG%')
plt.suptitle('NBA Effective Field Goal % 2000 - 2020', 
              fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'NBA Effective Field Goal % 2000 - 2020')
